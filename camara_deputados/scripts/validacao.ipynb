# %%
# %sql
select 
--*
count(1)
from
workspace.silver.orgaos
where 0=0
and codTipoOrgao in (4, 20)

# %%
# %sql
SHOW TABLES IN workspace.default

# %% [markdown]
# consulta tabela de log

# %%
# %sql

select *
from
workspace.metadata.ingestion_control
order by execution_time desc

# %% [markdown]
# volume by SQL

# %%
# %sql
SELECT *
FROM delta.`/Volumes/workspace/default/camara_deputados/bronze/eventos`
where 0=0
--and EXISTS (orgaos, x -> x.codTipoOrgao = 20) -- cpmi
and EXISTS (orgaos, x -> x['codTipoOrgao'] = 4)

# %% [markdown]
# volume by PYTHON (SPARK)

# %%
spark.read.format("delta").load(
    "/Volumes/workspace/default/camara_deputados/bronze/eventos"
).display()

# %% [markdown]
# tabela by PYTHON (SPARK)

# %%
spark.sql("""

SELECT *
FROM workspace.default.bronze_partidos
limite 100

""").display()

# %% [markdown]
# tabela by SQL

# %%
# %sql
SELECT count(*)
FROM workspace.default.bronze_partidos

# %% [markdown]
# apaga VOLUME

# %%
dbutils.fs.rm(
    "/Volumes/workspace/default/camara_deputados/logs/metadata_ingestion_control",
    recurse=True
)
