# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.gold;
CREATE SCHEMA IF NOT EXISTS workspace.metadata;
CREATE SCHEMA IF NOT EXISTS workspace.audit;

# %%
# %sql
ALTER TABLE workspace.default.metadata_ingestion_control
RENAME TO workspace.metadata.ingestion_control;

# %%
# %sql
ALTER TABLE workspace.default.silver_deputados
RENAME TO workspace.silver.deputados;

ALTER TABLE workspace.default.silver_partidos
RENAME TO workspace.silver.partidos;

ALTER TABLE workspace.default.silver_eventos
RENAME TO workspace.silver.eventos;

ALTER TABLE workspace.default.silver_orgaos
RENAME TO workspace.silver.orgaos;

ALTER TABLE workspace.default.silver_frentes
RENAME TO workspace.silver.frentes;

ALTER TABLE workspace.default.silver_proposicoes
RENAME TO workspace.silver.proposicoes;

ALTER TABLE workspace.default.silver_votacoes
RENAME TO workspace.silver.votacoes;
